# %% [markdown]
# <a href="https://colab.research.google.com/github/mschlemper/Alura-Store-MARCO-AURELIO-SCHLEMPER/blob/main/TelecomX_BR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracão

# %% [markdown]
# #🔧 Transformação

# %% [markdown]
# #📊 Carga e análise

# %% [markdown]
# #📄Relatorio Final

# %%
import pandas as pd

try:
  # Tenta ler o arquivo JSON
  df_telecom = pd.read_json('TelecomX_Data.json')

  # Mostra as primeiras linhas do DataFrame
  print("Dados importados com sucesso!")
  display(df_telecom.head())

except FileNotFoundError:
  print("Erro: O arquivo 'TelecomX_Data.json' não foi encontrado.")
  print("Certifique-se de que o arquivo está no local correto ou forneça o caminho completo para o arquivo.")
except Exception as e:
  print(f"Ocorreu um erro ao ler o arquivo JSON: {e}")

# %% [markdown]
# # Task
# Import the data from "TelecomX_Data.json" and use it to complete the notebook.

# %% [markdown]
# ## Exploração inicial dos dados
#
# ### Subtask:
# Analisar a estrutura e o conteúdo do DataFrame carregado do arquivo JSON para entender quais informações estão disponíveis e como elas podem ser utilizadas.

# %% [markdown]
# **Reasoning**:
# Analyze the structure and content of the DataFrame by displaying information, the first few rows, the columns, and descriptive statistics.

# %%
# 1. Exiba informações sobre o DataFrame, incluindo o tipo de dados de cada coluna e a contagem de valores não nulos.
print("Informações do DataFrame:")
df_telecom.info()

# 2. Mostre as primeiras 5 linhas do DataFrame para ter uma ideia da aparência dos dados.
print("\nPrimeiras 5 linhas do DataFrame:")
display(df_telecom.head())

# 3. Apresente as colunas presentes no DataFrame.
print("\nColunas do DataFrame:")
print(df_telecom.columns)

# 4. Obtenha estatísticas descritivas básicas do DataFrame.
print("\nEstatísticas descritivas para colunas numéricas:")
display(df_telecom.describe())

print("\nEstatísticas descritivas para colunas não numéricas:")
display(df_telecom.describe(include='object'))
# Out:
# Informações do DataFrame:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3971757933.py in <cell line: 0>()
#       1 # 1. Exiba informações sobre o DataFrame, incluindo o tipo de dados de cada coluna e a contagem de valores não nulos.
#       2 print("Informações do DataFrame:")
# ----> 3 df_telecom.info()
#       4
#       5 # 2. Mostre as primeiras 5 linhas do DataFrame para ter uma ideia da aparência dos dados.
#
# NameError: name 'df_telecom' is not defined

# %% [markdown]
# **Reasoning**:
# The previous command failed because the dataframe `df_telecom` was not defined. This is likely because the code cell that loaded the data was not executed or failed. I need to re-execute the code to load the data and then proceed with the analysis.

# %%
import pandas as pd

try:
  # Tenta ler o arquivo JSON
  df_telecom = pd.read_json('TelecomX_Data.json')

  # Mostra as primeiras linhas do DataFrame
  print("Dados importados com sucesso!")
  display(df_telecom.head())

except FileNotFoundError:
  print("Erro: O arquivo 'TelecomX_Data.json' não foi encontrado.")
  print("Certifique-se de que o arquivo está no local correto ou forneça o caminho completo para o arquivo.")
except Exception as e:
  print(f"Ocorreu um erro ao ler o arquivo JSON: {e}")

# 1. Exiba informações sobre o DataFrame, incluindo o tipo de dados de cada coluna e a contagem de valores não nulos.
print("\nInformações do DataFrame:")
df_telecom.info()

# 2. Mostre as primeiras 5 linhas do DataFrame para ter uma ideia da aparência dos dados.
print("\nPrimeiras 5 linhas do DataFrame:")
display(df_telecom.head())

# 3. Apresente as colunas presentes no DataFrame.
print("\nColunas do DataFrame:")
print(df_telecom.columns)

# 4. Obtenha estatísticas descritivas básicas do DataFrame.
print("\nEstatísticas descritivas para colunas numéricas:")
display(df_telecom.describe())

print("\nEstatísticas descritivas para colunas não numéricas:")
display(df_telecom.describe(include='object'))
# Out:
# Erro: O arquivo 'TelecomX_Data.json' não foi encontrado.
# Certifique-se de que o arquivo está no local correto ou forneça o caminho completo para o arquivo.
#
# Informações do DataFrame:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-373511447.py in <cell line: 0>()
#      17 # 1. Exiba informações sobre o DataFrame, incluindo o tipo de dados de cada coluna e a contagem de valores não nulos.
#      18 print("\nInformações do DataFrame:")
# ---> 19 df_telecom.info()
#      20
#      21 # 2. Mostre as primeiras 5 linhas do DataFrame para ter uma ideia da aparência dos dados.
#
# NameError: name 'df_telecom' is not defined

# %% [markdown]
# ## Definição dos objetivos
#
# ### Subtask:
# Entender quais são os objetivos específicos de cada seção do notebook ("Transformação", "Carga e Análise", "Relatório Final") para direcionar as etapas seguintes.

# %% [markdown]
# **Reasoning**:
# Review the markdown cells to identify the section titles and infer their objectives based on standard data science workflow.

# %%
print("Section: Extração - Objective: Data extraction/loading, already completed by loading the JSON file.")
print("Section: Transformação - Objective: Data cleaning, handling missing values, feature engineering, and data preparation for analysis.")
print("Section: Carga e Análise - Objective: Loading the transformed data (if saved), performing data analysis, visualization, and potentially model training.")
print("Section: Relatório Final - Objective: Summarizing findings, presenting results, and concluding the analysis.")
# Out:
# Section: Extração - Objective: Data extraction/loading, already completed by loading the JSON file.
# Section: Transformação - Objective: Data cleaning, handling missing values, feature engineering, and data preparation for analysis.
# Section: Carga e Análise - Objective: Loading the transformed data (if saved), performing data analysis, visualization, and potentially model training.
# Section: Relatório Final - Objective: Summarizing findings, presenting results, and concluding the analysis.

# %% [markdown]
# ## Transformação dos dados
#
# ### Subtask:
# Com base nos objetivos, realizar as transformações necessárias nos dados (por exemplo, limpeza, criação de novas colunas, agregação) para prepará-los para a análise.

# %% [markdown]
# **Reasoning**:
# Check for missing values and display the count per column to understand the extent of missing data.

# %%
print("Checking for missing values:")
display(df_telecom.isnull().sum())
# Out:
# Checking for missing values:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2219962248.py in <cell line: 0>()
#       1 print("Checking for missing values:")
# ----> 2 display(df_telecom.isnull().sum())
#
# NameError: name 'df_telecom' is not defined

# %% [markdown]
# **Reasoning**:
# The DataFrame `df_telecom` was not found, likely due to a previous error in loading the data. Attempt to reload the data and then check for missing values as originally intended.

# %%
import pandas as pd

try:
  # Tenta ler o arquivo JSON novamente
  df_telecom = pd.read_json('TelecomX_Data.json')

  # Mostra as primeiras linhas do DataFrame para verificar o carregamento
  print("Dados importados com sucesso novamente!")
  display(df_telecom.head())

  # Check for missing values
  print("\nChecking for missing values:")
  display(df_telecom.isnull().sum())

except FileNotFoundError:
  print("Erro: O arquivo 'TelecomX_Data.json' não foi encontrado.")
  print("Certifique-se de que o arquivo está no local correto ou forneça o caminho completo para o arquivo.")
except Exception as e:
  print(f"Ocorreu um erro ao ler o arquivo JSON: {e}")
# Out:
# Erro: O arquivo 'TelecomX_Data.json' não foi encontrado.
# Certifique-se de que o arquivo está no local correto ou forneça o caminho completo para o arquivo.

# %% [markdown]
# ## Carga e análise
#
# ### Subtask:
# Carregar os dados transformados e realizar as análises solicitadas ou relevantes para os dados de telecomunicações.

# %% [markdown]
# **Reasoning**:
# Since the previous steps failed to load the data, the first step in this subtask is to attempt to load the data again using a try-except block and then proceed with basic analysis if successful.

# %%
import pandas as pd

try:
  # Tenta ler o arquivo JSON novamente
  df_telecom = pd.read_json('TelecomX_Data.json')

  print("Dados importados com sucesso para a análise!")
  display(df_telecom.head())

  # Realizar uma análise inicial - Exemplo: Exibir estatísticas descritivas
  print("\nEstatísticas descritivas dos dados:")
  display(df_telecom.describe())

  # Exemplo: Verificar a distribuição de uma coluna categórica se houver
  # Substitua 'nome_da_coluna_categorica' pelo nome de uma coluna categórica real
  # if 'nome_da_coluna_categorica' in df_telecom.columns:
  #     print(f"\nDistribuição da coluna 'nome_da_coluna_categorica':")
  #     display(df_telecom['nome_da_coluna_categorica'].value_counts())

  # Exemplo: Verificar a correlação entre colunas numéricas se houver
  # if df_telecom.select_dtypes(include=['number']).shape[1] > 1:
  #     print("\nMatriz de Correlação:")
  #     display(df_telecom.select_dtypes(include=['number']).corr())


except FileNotFoundError:
  print("Erro: O arquivo 'TelecomX_Data.json' não foi encontrado.")
  print("A análise dos dados não pode ser realizada sem o arquivo de dados.")
except Exception as e:
  print(f"Ocorreu um erro ao ler o arquivo JSON: {e}")
  print("A análise dos dados não pode ser realizada devido ao erro na leitura do arquivo.")
# Out:
# Erro: O arquivo 'TelecomX_Data.json' não foi encontrado.
# A análise dos dados não pode ser realizada sem o arquivo de dados.

# %% [markdown]
# ## Geração do relatório final
#
# ### Subtask:
# Apresentar os principais insights e resultados da análise de forma clara e concisa na seção de relatório.

# %% [markdown]
# **Reasoning**:
# Since the data file could not be loaded and analyzed in the previous steps, the final report section must reflect this and summarize the attempts made and the reason for the incomplete analysis, rather than presenting data insights.

# %%
# This cell will contain the final report summary.
# As the data file "TelecomX_Data.json" could not be loaded in previous steps,
# a full data transformation, analysis, and presentation of findings were not possible.

print("## Relatório Final")
print("\nResumo do Processo:\n")
print("O objetivo deste notebook era realizar uma análise de dados de telecomunicações a partir do arquivo 'TelecomX_Data.json'. O processo planejado incluía as etapas de Extração, Transformação, Carga e Análise, culminando em um relatório final com os principais insights.")
print("\nStatus das Etapas:\n")
print("- **Extração:** Foi feita uma tentativa de carregar os dados do arquivo 'TelecomX_Data.json' utilizando a biblioteca pandas. No entanto, o arquivo não foi encontrado no local especificado, resultando em um erro `FileNotFoundError`. Portanto, esta etapa não foi concluída com sucesso.")
print("- **Transformação:** Devido à falha na etapa de Extração, não foi possível carregar os dados no DataFrame `df_telecom`. Consequentemente, a etapa de Transformação, que envolveria limpeza, tratamento de valores ausentes e engenharia de features, não pôde ser realizada.")
print("- **Carga e Análise:** Similarmente, a ausência dos dados impediu a realização da etapa de Carga e Análise. Nenhuma análise exploratória, visualização ou qualquer outra forma de análise de dados pôde ser executada sem o DataFrame carregado.")
print("\nConclusão:\n")
print("A análise completa dos dados de telecomunicações não foi possível devido à indisponibilidade do arquivo 'TelecomX_Data.json'. As etapas de Transformação e Carga e Análise não puderam ser executadas. O presente relatório se limita a documentar as tentativas realizadas e a razão pela qual o processo analítico não pôde ser concluído conforme planejado.")
print("\n[Se os dados estivessem disponíveis e a análise fosse concluída, os principais insights, resultados da análise exploratória, visualizações e quaisquer conclusões derivadas seriam apresentados aqui.]")
# Out:
# ## Relatório Final
#
# Resumo do Processo:
#
# O objetivo deste notebook era realizar uma análise de dados de telecomunicações a partir do arquivo 'TelecomX_Data.json'. O processo planejado incluía as etapas de Extração, Transformação, Carga e Análise, culminando em um relatório final com os principais insights.
#
# Status das Etapas:
#
# - **Extração:** Foi feita uma tentativa de carregar os dados do arquivo 'TelecomX_Data.json' utilizando a biblioteca pandas. No entanto, o arquivo não foi encontrado no local especificado, resultando em um erro `FileNotFoundError`. Portanto, esta etapa não foi concluída com sucesso.
# - **Transformação:** Devido à falha na etapa de Extração, não foi possível carregar os dados no DataFrame `df_telecom`. Consequentemente, a etapa de Transformação, que envolveria limpeza, tratamento de valores ausentes e engenharia de features, não pôde ser realizada.
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The primary obstacle encountered throughout the process was the unavailability of the "TelecomX\_Data.json" file.
# *   Due to the `FileNotFoundError`, the data could not be loaded into a pandas DataFrame.
# *   Consequently, the planned data transformation, loading, and analysis steps could not be executed.
# *   The final report section was adapted to document the failure to load the data and the resulting inability to perform the analysis, including a placeholder for potential future insights if the data becomes available.
#
# ### Insights or Next Steps
#
# *   The immediate next step is to ensure the "TelecomX\_Data.json" file is accessible in the correct path to allow the data loading and subsequent analysis to proceed.
# *   Once the data is loaded, the analysis can begin with checking for missing values, performing necessary transformations, and conducting exploratory data analysis as originally intended.

# %% [markdown]
# ## Exploração inicial dos dados
#
# ### Subtask:
# Analisar a estrutura e o conteúdo do DataFrame carregado do arquivo JSON para entender quais informações estão disponíveis e como elas podem ser utilizadas.

# %% [markdown]
# **Reasoning**:
# Analyze the structure and content of the DataFrame by displaying information, the first few rows, the columns, and descriptive statistics.

# %%
# 1. Exiba informações sobre o DataFrame, incluindo o tipo de dados de cada coluna e a contagem de valores não nulos.
print("Informações do DataFrame:")
df_telecom.info()

# 2. Mostre as primeiras 5 linhas do DataFrame para ter uma ideia da aparência dos dados.
print("\nPrimeiras 5 linhas do DataFrame:")
display(df_telecom.head())

# 3. Apresente as colunas presentes no DataFrame.
print("\nColunas do DataFrame:")
print(df_telecom.columns)

# 4. Obtenha estatísticas descritivas básicas do DataFrame.
print("\nEstatísticas descritivas para colunas numéricas:")
display(df_telecom.describe())

print("\nEstatísticas descritivas para colunas não numéricas:")
display(df_telecom.describe(include='object'))
# Out:
# Informações do DataFrame:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3971757933.py in <cell line: 0>()
#       1 # 1. Exiba informações sobre o DataFrame, incluindo o tipo de dados de cada coluna e a contagem de valores não nulos.
#       2 print("Informações do DataFrame:")
# ----> 3 df_telecom.info()
#       4
#       5 # 2. Mostre as primeiras 5 linhas do DataFrame para ter uma ideia da aparência dos dados.
#
# NameError: name 'df_telecom' is not defined

# %% [markdown]
# **Reasoning**:
# The DataFrame `df_telecom` was not found, likely due to a previous error in loading the data. Attempt to reload the data and then proceed with the initial data exploration as originally intended.

# %%
import pandas as pd

try:
  # Tenta ler o arquivo JSON novamente
  df_telecom = pd.read_json('TelecomX_Data.json')

  # Mostra as primeiras linhas do DataFrame para verificar o carregamento
  print("Dados importados com sucesso novamente!")
  display(df_telecom.head())

  # 1. Exiba informações sobre o DataFrame, incluindo o tipo de dados de cada coluna e a contagem de valores não nulos.
  print("\nInformações do DataFrame:")
  df_telecom.info()

  # 2. Mostre as primeiras 5 linhas do DataFrame para ter uma ideia da aparência dos dados.
  print("\nPrimeiras 5 linhas do DataFrame:")
  display(df_telecom.head())

  # 3. Apresente as colunas presentes no DataFrame.
  print("\nColunas do DataFrame:")
  print(df_telecom.columns)

  # 4. Obtenha estatísticas descritivas básicas do DataFrame.
  print("\nEstatísticas descritivas para colunas numéricas:")
  display(df_telecom.describe())

  print("\nEstatísticas descritivas para colunas não numéricas:")
  display(df_telecom.describe(include='object'))

except FileNotFoundError:
  print("Erro: O arquivo 'TelecomX_Data.json' não foi encontrado.")
  print("Certifique-se de que o arquivo está no local correto ou forneça o caminho completo para o arquivo.")
except Exception as e:
  print(f"Ocorreu um erro ao ler o arquivo JSON: {e}")
# Out:
# Erro: O arquivo 'TelecomX_Data.json' não foi encontrado.
# Certifique-se de que o arquivo está no local correto ou forneça o caminho completo para o arquivo.

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print(f'Arquivo "{fn}" enviado com sucesso!')
# Out:
#      <input type="file" id="files-300bb3a1-6ffb-4113-a554-9204ad425257" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-300bb3a1-6ffb-4113-a554-9204ad425257">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## Exploração inicial dos dados
#
# ### Subtask:
# Analisar a estrutura e o conteúdo do DataFrame carregado do arquivo JSON para entender quais informações estão disponíveis e como elas podem ser utilizadas.

# %% [markdown]
# **Reasoning**:
# Analyze the structure and content of the DataFrame by displaying information, the first few rows, the columns, and descriptive statistics.

# %%
import pandas as pd

try:
  # Tenta ler o arquivo JSON novamente
  df_telecom = pd.read_json('TelecomX_Data.json')

  # Mostra as primeiras linhas do DataFrame para verificar o carregamento
  print("Dados importados com sucesso novamente!")
  display(df_telecom.head())

  # 1. Exiba informações sobre o DataFrame, incluindo o tipo de dados de cada coluna e a contagem de valores não nulos.
  print("\nInformações do DataFrame:")
  df_telecom.info()

  # 2. Mostre as primeiras 5 linhas do DataFrame para ter uma ideia da aparência dos dados.
  print("\nPrimeiras 5 linhas do DataFrame:")
  display(df_telecom.head())

  # 3. Apresente as colunas presentes no DataFrame.
  print("\nColunas do DataFrame:")
  print(df_telecom.columns)

  # 4. Obtenha estatísticas descritivas básicas do DataFrame.
  print("\nEstatísticas descritivas para colunas numéricas:")
  display(df_telecom.describe())

  print("\nEstatísticas descritivas para colunas não numéricas:")
  display(df_telecom.describe(include='object'))

except FileNotFoundError:
  print("Erro: O arquivo 'TelecomX_Data.json' não foi encontrado.")
  print("Certifique-se de que o arquivo está no local correto ou forneça o caminho completo para o arquivo.")
except Exception as e:
  print(f"Ocorreu um erro ao ler o arquivo JSON: {e}")
# Out:
# Dados importados com sucesso novamente!
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# ...

# %% [markdown]
# ## Transformação dos dados
#
# ### Subtask:
# Achatar as colunas aninhadas ('customer', 'phone', 'internet', 'account') no DataFrame principal para facilitar a análise.

# %% [markdown]
# **Reasoning**:
# The columns 'customer', 'phone', 'internet', and 'account' contain nested dictionary-like structures. These need to be flattened into individual columns to make the data accessible for analysis.

# %%
# Flatten the 'customer' column
customer_df = pd.json_normalize(df_telecom['customer'])
df_telecom = pd.concat([df_telecom.drop('customer', axis=1), customer_df], axis=1)

# Flatten the 'phone' column
phone_df = pd.json_normalize(df_telecom['phone'])
df_telecom = pd.concat([df_telecom.drop('phone', axis=1), phone_df], axis=1)

# Flatten the 'internet' column
internet_df = pd.json_normalize(df_telecom['internet'])
df_telecom = pd.concat([df_telecom.drop('internet', axis=1), internet_df], axis=1)

# Flatten the 'account' column
account_df = pd.json_normalize(df_telecom['account'])
df_telecom = pd.concat([df_telecom.drop('account', axis=1), account_df], axis=1)

# Display the first few rows of the transformed DataFrame to verify
print("DataFrame após 'achatar' as colunas aninhadas:")
display(df_telecom.head())

# Display information about the transformed DataFrame
print("\nInformações do DataFrame transformado:")
df_telecom.info()
# Out:
# DataFrame após 'achatar' as colunas aninhadas:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %% [markdown]
# ## Carga e análise
#
# ### Subtask:
# Verificar a presença de valores ausentes no DataFrame transformado para identificar a necessidade de tratamento.

# %% [markdown]
# **Reasoning**:
# Check for missing values in the transformed DataFrame to understand the data quality and identify columns that might require imputation or removal.

# %%
print("Verificando valores ausentes no DataFrame transformado:")
display(df_telecom.isnull().sum())
# Out:
# Verificando valores ausentes no DataFrame transformado:
# customerID          0
# Churn               0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Charges.Monthly     0
# Charges.Total       0
# dtype: int64

# %% [markdown]
# ### Subtask:
# Converter a coluna 'Charges.Total' para um tipo numérico, tratando possíveis valores não numéricos que impediram a conversão automática durante o carregamento.

# %% [markdown]
# **Reasoning**:
# The 'Charges.Total' column was identified as an 'object' type but represents numerical data. It needs to be converted to a numeric type for proper analysis. Non-numeric values (potentially empty strings) should be handled, likely by converting them to NaN and then filling with 0, as per common practice with such columns in telecom datasets where empty total charges might indicate new customers.

# %%
# Convert 'Charges.Total' to numeric, coercing errors and filling NaNs with 0
df_telecom['Charges.Total'] = pd.to_numeric(df_telecom['Charges.Total'], errors='coerce').fillna(0)

# Verify the data type after conversion
print("Tipo de dados da coluna 'Charges.Total' após a conversão:")
print(df_telecom['Charges.Total'].dtype)

# Display descriptive statistics for 'Charges.Total' to confirm conversion
print("\nEstatísticas descritivas para a coluna 'Charges.Total':")
display(df_telecom['Charges.Total'].describe())
# Out:
# Tipo de dados da coluna 'Charges.Total' após a conversão:
# float64
#
# Estatísticas descritivas para a coluna 'Charges.Total':
# count    7267.000000
# mean     2277.182035
# std      2268.648587
# min         0.000000
# 25%       396.200000
# 50%      1389.200000
# 75%      3778.525000
# max      8684.800000
# Name: Charges.Total, dtype: float64

# %% [markdown]
# ## Carga e análise
#
# ### Subtask:
# Realizar análises exploratórias básicas e visualizações para entender as características dos dados e identificar padrões.

# %% [markdown]
# **Reasoning**:
# With the data loaded, flattened, and cleaned (handling missing values and data types), perform some basic exploratory data analysis (EDA) to gain insights into the dataset. This can include looking at the distribution of churn, examining relationships between churn and other variables (e.g., tenure, monthly charges), and visualizing key features.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Analyze the distribution of Churn
print("\nDistribuição de Churn:")
display(df_telecom['Churn'].value_counts())
display(df_telecom['Churn'].value_counts(normalize=True) * 100)

plt.figure(figsize=(6, 4))
sns.countplot(x='Churn', data=df_telecom)
plt.title('Distribuição de Churn')
plt.show()

# Explore the relationship between Tenure and Churn
print("\nEstatísticas de Tenure por Churn:")
display(df_telecom.groupby('Churn')['tenure'].describe())

plt.figure(figsize=(8, 5))
sns.boxplot(x='Churn', y='tenure', data=df_telecom)
plt.title('Tenure vs. Churn')
plt.show()

# Explore the relationship between Monthly Charges and Churn
print("\nEstatísticas de Charges.Monthly por Churn:")
display(df_telecom.groupby('Churn')['Charges.Monthly'].describe())

plt.figure(figsize=(8, 5))
sns.boxplot(x='Churn', y='Charges.Monthly', data=df_telecom)
plt.title('Charges.Monthly vs. Churn')
plt.show()
# Out:
# Distribuição de Churn:
# Churn
# No     5174
# Yes    1869
#         224
# Name: count, dtype: int64
# Churn
# No     71.198569
# Yes    25.719004
#         3.082427
# Name: proportion, dtype: float64
# Estatísticas de Tenure por Churn:
#         count       mean        std  min   25%   50%   75%   max
# Churn
#         224.0  31.571429  24.998552  1.0   7.0  29.0  56.0  72.0
# No     5174.0  37.569965  24.113777  0.0  15.0  38.0  61.0  72.0
# Yes    1869.0  17.979133  19.531123  1.0   2.0  10.0  29.0  72.0
# Estatísticas de Charges.Monthly por Churn:
#         count       mean        std    min     25%     50%      75%     max
# Churn
#         224.0  63.412277  31.388712  18.75  28.425  69.100  90.4125  115.55
# No     5174.0  61.265124  31.092648  18.25  25.100  64.425  88.4000  118.75
# Yes    1869.0  74.441332  24.666053  18.85  56.150  79.650  94.2000  118.35

# %% [markdown]
# ## Relatório Final
#
# ### Subtask:
# Summarize the data loading, transformation, and analysis process, and present key findings.

# %% [markdown]
# **Reasoning**:
# Conclude the notebook by summarizing the steps taken, including data loading, flattening, and basic exploratory analysis. Highlight any initial observations or patterns identified during the analysis phase, particularly regarding customer churn and its relationship with other features like tenure and monthly charges.

# %%
# This cell will contain the final report summary based on the completed steps.

print("## Relatório Final")
print("\nResumo do Processo:\n")
print("Este notebook realizou a análise inicial de dados de telecomunicações a partir do arquivo 'TelecomX_Data.json'. O processo incluiu as seguintes etapas:")
print("\n- **Extração:** Carregamento bem-sucedido dos dados do arquivo JSON para um DataFrame pandas.")
print("- **Transformação:** 'Achatamento' das colunas aninhadas ('customer', 'phone', 'internet', 'account') para facilitar o acesso aos dados. A coluna 'Charges.Total' foi convertida para um tipo numérico, tratando valores não numéricos.")
print("- **Carga e Análise:** Verificação da ausência de valores nulos (nenhum encontrado) e realização de análises exploratórias básicas para entender a distribuição de Churn e sua relação com 'tenure' e 'Charges.Monthly'.")
print("\nPrincipais Observações Preliminares:\n")
print(f"- A distribuição de Churn mostra que aproximadamente {df_telecom['Churn'].value_counts(normalize=True)['Yes']:.2%} dos clientes na amostra cancelaram o serviço.")
print("- Clientes que cancelaram ('Yes') parecem ter uma tenure (tempo de permanência) menor em comparação com aqueles que não cancelaram ('No').")
print("- Clientes que cancelaram ('Yes') tendem a ter 'Charges.Monthly' (cobranças mensais) mais altas em média do que aqueles que não cancelaram ('No').")
print("\nPróximos Passos (Sugestões):\n")
print("- Investigação mais aprofundada das relações entre Churn e outras variáveis categóricas e numéricas.")
print("- Engenharia de features para criar novas variáveis que possam ser úteis para modelagem (por exemplo, criar faixas etárias a partir de SeniorCitizen, agrupar PaymentMethod).")
print("- Preparação dos dados para modelagem preditiva de Churn, incluindo codificação de variáveis categóricas e escalonamento de variáveis numéricas.")
print("- Construção e avaliação de modelos de Machine Learning para prever o Churn do cliente.")
print("- Apresentação dos resultados e insights de forma mais detalhada, possivelmente com visualizações adicionais e tabelas.")
# Out:
# ## Relatório Final
#
# Resumo do Processo:
#
# Este notebook realizou a análise inicial de dados de telecomunicações a partir do arquivo 'TelecomX_Data.json'. O processo incluiu as seguintes etapas:
#
# - **Extração:** Carregamento bem-sucedido dos dados do arquivo JSON para um DataFrame pandas.
# - **Transformação:** 'Achatamento' das colunas aninhadas ('customer', 'phone', 'internet', 'account') para facilitar o acesso aos dados. A coluna 'Charges.Total' foi convertida para um tipo numérico, tratando valores não numéricos.
# - **Carga e Análise:** Verificação da ausência de valores nulos (nenhum encontrado) e realização de análises exploratórias básicas para entender a distribuição de Churn e sua relação com 'tenure' e 'Charges.Monthly'.
#
# Principais Observações Preliminares:
#
# - A distribuição de Churn mostra que aproximadamente 25.72% dos clientes na amostra cancelaram o serviço.
# ...
